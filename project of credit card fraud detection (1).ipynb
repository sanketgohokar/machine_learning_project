# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df=pd.read_csv("creditcard.csv")

# %% [markdown]
# # Display Top 5 Rows of dataset

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# # Check Last 5 rows of the dataset

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %% [markdown]
# # Find shape of our dataset

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# # Get information about our dataaset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Check Null values in dataset

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df=df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
df.shape
# Out:
# (284807, 30)

# %%
df.duplicated().any()
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %% [markdown]
# # Exploratoty Data Analysis(EDA) & Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
sns.countplot(data=df, x="Class")
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
x = df.drop('Class',axis=1)
y = df['Class']

# %% [markdown]
# # Data is imbalance
# To Handling the IMBALANCE data

# %% [markdown]
# # by using Undersampling

# %%
normal = df[df['Class']==0]
fraud  = df[df['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.103261 -0.057338  0.530557  0.922982 -0.192496  0.338575 -0.295650
# 1 -0.876267  0.989878  1.109144  0.431674  0.082297 -0.127250  0.932109
# 2 -0.670299  0.798682  1.995501  0.624464  0.208849  0.114763  0.472583
# 3 -0.772209  0.919101 -0.116729 -0.687063  1.085262  4.443044 -2.424143
# 4  0.053789  0.868106  0.233310 -0.620263  0.485915 -1.038578  1.017066
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.128911  0.389341 -0.113901 -0.902372  0.071811  0.294530  0.095394
# 1 -0.055072 -0.917607  0.278672  1.802806  0.810689  0.226109  0.447072
# 2  0.292088 -0.762256 -0.099273  0.134866 -0.280972 -1.598702  0.141360
# 3 -1.021778 -0.303335 -0.923202 -0.523998  0.128150  0.114085  0.547947
# 4 -0.203745 -0.049037 -0.413875 -1.042149  0.140296  0.132853  0.084259
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %% [markdown]
# # Splitting data into traning and testing

# %%
x = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_train.shape
# Out:
# (756, 29)

# %%
x_test.shape
# Out:
# (190, 29)

# %%
y_train.shape
# Out:
# (756,)

# %%
y_test.shape
# Out:
# (190,)

# %% [markdown]
# # Apply the Logestic Regression
# because its classification problem so we using classification algorithms

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 =log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9263157894736842

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9489795918367347

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9300000000000002

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 =dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8952380952380953

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9082125603864734

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9583333333333334

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9292929292929293

# %% [markdown]
# # To check the Models Accuracy using barplot

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF'],'ACC':[accuracy_score(y_test,y_pred1)*100,accuracy_score(y_test,y_pred2)*100,accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  92.631579
# 1     DT  90.000000
# 2     RF  92.631579

# %%
sns.barplot(x='Models', y='ACC', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # Random Forest algorithm after using undersampling the data accuracy is 93.157895 is good

# %% [markdown]
# # *** Oversampling

# %% [markdown]
# Using oversampling by Techniques like SMOTE (Synthetic Minority Over-sampling Technique) can create synthetic samples for the minority class to balance the dataset

# %%
x = df.drop('Class',axis=1)
y = df['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res,y_res=SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: Class, dtype: int64

# %% [markdown]
# Spliting the data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_res,y_res,test_size=0.20,random_state=42)

# %% [markdown]
# # Logistic Regression after Oversampling

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9432755550710418

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9726266405598744

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.912150246350199

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9414181975118683

# %% [markdown]
# # Decision Tree classifier after oversampling

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9982648352047676

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.997621382140393

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9989091504099776

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9982648509679588

# %% [markdown]
# # Random Forest classifier after oversampling

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9999000690432065

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998000508961356

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999000154521575

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF'],'ACC':[accuracy_score(y_test,y_pred1)*100,accuracy_score(y_test,y_pred2)*100,accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.327556
# 1     DT  99.826484
# 2     RF  99.990007

# %%
sns.barplot(x='Models', y='ACC', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # Conclusion:- Using oversampling by Techniques like SMOTE (Synthetic Minority Over-sampling Technique)  after Random Forest classifier is best working on data
